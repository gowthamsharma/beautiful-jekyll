# %% [markdown]
# Analysis of famous Titanic data set using pandas basic functionalities
# I intend to update this analysis as and when i learn about new pandas functionalities.

# %% [raw]
# Variable              Definition	            Key
# survival	          Survival	                0 = No, 1 = Yes
# pclass	              Ticket class	            1 = 1st, 2 = 2nd, 3 = 3rd
# sex	                  Sex
# Age	                  Age in years
# sibsp	              # of siblings / spouses aboard the Titanic
# parch	              # of parents / children aboard the Titanic
# ticket	              Ticket number
# fare	              Passenger fare
# cabin	              Cabin number
# embarked              Port of Embarkation	   C = Cherbourg, Q = Queenstown, S = Southampton
#
#
# Variable Notes
# pclass: A proxy for socio-economic status (SES)
# 1st = Upper
# 2nd = Middle
# 3rd = Lower
#
# age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# sibsp: The dataset defines family relations in this way...
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# parch: The dataset defines family relations in this way...
# Parent = mother, father
# Child = daughter, son, stepdaughter, stepson
# Some children travelled only with a nanny, therefore parch=0 for them.

# %% [markdown]
# # Get the Data

# %% [markdown]
# #### - import can be from .csv .txt .xlm and many other kinds of files

# %%
import pandas as pd

# %%
titanic =  pd.read_csv('titanic.csv')

# %% [markdown]
# #### Initial Inspection of data

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#### you can also input data using pd.read_table()

# %%
titanic.Name.head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
titanic['Name'].head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
titanic['Ticket_Cabin'] = titanic.Ticket + ',' + titanic.Cabin

# %%
titanic.Ticket_Cabin.head() # creates a nan value if either column is nan
# Out:
# 0             NaN
# 1    PC 17599,C85
# 2             NaN
# 3     113803,C123
# 4             NaN
# Name: Ticket_Cabin, dtype: object

# %%
titanic['Ticket_Cabin_ignoreNaN'] = titanic.Ticket.fillna('') + ',' + titanic.Cabin.fillna('')

# %%
titanic.Ticket_Cabin_ignoreNaN.head() # this resolves NaN problem when adding NaN with a sting
# Out:
# 0           A/5 21171,
# 1         PC 17599,C85
# 2    STON/O2. 3101282,
# 3          113803,C123
# 4              373450,
# Name: Ticket_Cabin_ignoreNaN, dtype: object

# %% [markdown]
# # Sampling Huge data sets

# %%
titanic.sample(n=20, random_state=14) # random sampling of 20 rows ; 'random_state' parameter for reproducibility ; reproducing the same set of outcomes
# Out:
#      PassengerId  Survived  Pclass  \
# 75            76         0       3
# 602          603         0       1
# 119          120         0       3
# 647          648         1       1
# 115          116         0       3
# 472          473         1       2
# 547          548         1       2
# 735          736         0       3
# 467          468         0       1
# 759          760         1       1
# 773          774         0       3
# 506          507         1       2
# 197          198         0       3
# 425          426         0       3
# 53            54         1       2
# 553          554         1       3
# 265          266         0       2
# 397          398         0       2
# 569          570         1       3
# 180          181         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 75                             Moen, Mr. Sigurd Hansen    male  25.0      0
# ...

# %%
fraction1 = titanic.sample(frac=.02, random_state=14)
fraction1
# Out:
#      PassengerId  Survived  Pclass  \
# 75            76         0       3
# 602          603         0       1
# 119          120         0       3
# 647          648         1       1
# 115          116         0       3
# 472          473         1       2
# 547          548         1       2
# 735          736         0       3
# 467          468         0       1
# 759          760         1       1
# 773          774         0       3
# 506          507         1       2
# 197          198         0       3
# 425          426         0       3
# 53            54         1       2
# 553          554         1       3
# 265          266         0       2
# 397          398         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 75                             Moen, Mr. Sigurd Hansen    male  25.0      0
# 602                          Harrington, Mr. Charles H    male   NaN      0
# ...

# %%
fraction2 = titanic.loc[~titanic.index.isin(fraction1.index), :]  #rest of the fraction stored in variable fraction2
fraction2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# # describe()

# %% [markdown]
# ## one thing to always remember is Methods end with parentheses, while attributes don't

# %%
titanic.describe() # Parch is parents or children abroad
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.describe(include=['object'])
# Out:
#                                  Name   Sex Ticket    Cabin Embarked  \
# count                             891   891    891      204      889
# unique                            891     2    681      147        3
# top     Somerton, Mr. Francis William  male   1601  B96 B98        S
# freq                                1   577      7        4      644
#
#              Ticket_Cabin Ticket_Cabin_ignoreNaN
# count                 204                    891
# unique                161                    710
# top     19950,C23 C25 C27                347082,
# freq                    4                      7

# %%
titanic.describe().loc['25%','Fare']
# Out:
# 7.9104

# %% [markdown]
# # .value_counts()

# %%
titanic.Survived.value_counts() # How many survivors?
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
titanic.Sex.value_counts()['male'] # number of male passengers
# Out:
# 577

# %%
titanic.Survived.value_counts(normalize=True) # value counts displayed proportionately
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %%
titanic.Pclass.value_counts().plot(kind='bar')

# %% [markdown]
# # .unique() .nunique()

# %%
titanic.Age.unique() # there were 88 passengers with unique Ages
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
titanic.Age.nunique()
# Out:
# 88

# %% [markdown]
# # drop columns

# %%
titanic.drop('Ticket_Cabin', axis=1, inplace=True)

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked',
#        'Ticket_Cabin_ignoreNaN'],
#       dtype='object')

# %% [markdown]
# # drop multiple columns at once

# %%
titanic.drop(['SibSp', 'Parch'], axis=1, inplace=True) # we use inplace=True, if you don't want to save the updated data to the same variable

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#              Ticket     Fare Cabin Embarked Ticket_Cabin_ignoreNaN
# 0         A/5 21171   7.2500   NaN        S             A/5 21171,
# 1          PC 17599  71.2833   C85        C           PC 17599,C85
# 2  STON/O2. 3101282   7.9250   NaN        S      STON/O2. 3101282,
# 3            113803  53.1000  C123        S            113803,C123
# ...

# %% [markdown]
# # drop multiple rows at once

# %%
titanic.drop([0,2], axis=0, inplace=False) #  use inplace=True, if you don't want to save the updated data to the same variable
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# ...

# %% [markdown]
# # sort values according to a column feature

# %%
titanic.Age.sort_values().head()
# Out:
# 803    0.42
# 755    0.67
# 644    0.75
# 469    0.75
# 78     0.83
# Name: Age, dtype: float64

# %% [markdown]
# # Sort Entire dataframe by a column

# %%
titanic.sort_values('Age').head(8)  # view signature for more info
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 831          832         1       2  Richards, Master. George Sibley    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 827          828         1       2            Mallet, Master. Andre    male
#
#       Age           Ticket      Fare    Cabin Embarked Ticket_Cabin_ignoreNaN
# 803  0.42             2625    8.5167      NaN        C                  2625,
# 755  0.67           250649   14.5000      NaN        S                250649,
# ...

# %%
titanic.sort_values('Age', ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age    Ticket     Fare Cabin Embarked Ticket_Cabin_ignoreNaN
# 630  male  80.0     27042  30.0000   A23        S              27042,A23
# 851  male  74.0    347060   7.7750   NaN        S                347060,
# 493  male  71.0  PC 17609  49.5042   NaN        C              PC 17609,
# 96   male  71.0  PC 17754  34.6542    A5        C            PC 17754,A5
# 116  male  70.5    370369   7.7500   NaN        Q                370369,

# %% [markdown]
# # Traverse a dataframe

# %%
for index,data in enumerate(titanic.Name):
    print(data)
    print(index)
    if index==4:
        break
# Out:
# Braund, Mr. Owen Harris
# 0
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# 1
# Heikkinen, Miss. Laina
# 2
# Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 3
# Allen, Mr. William Henry
# 4

# %%
for index,row in titanic.iterrows():
    print(row.Name, '    ', row.Fare)
    if index==4:
        break
# Out:
# Braund, Mr. Owen Harris      7.25
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)      71.2833
# Heikkinen, Miss. Laina      7.925
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      53.1
# Allen, Mr. William Henry      8.05

# %% [markdown]
# # convert the pandas list to a numpy Series

# %%
name =  pd.Series(titanic.Name)
name.head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %% [markdown]
# # filtering a dataframe

# %%
titanic[titanic.Age<=1]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 164          165         0       3     Panula, Master. Eino Viljami    male
# 172          173         1       3     Johnson, Miss. Eleanor Ileen  female
# 183          184         1       2        Becker, Master. Richard F    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 381          382         1       3      Nakid, Miss. Maria ("Mary")  female
# 386          387         0       3  Goodwin, Master. Sidney Leonard    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 788          789         1       3       Dean, Master. Bertram Vere    male
# ...

# %%
titanic[titanic.Age<=1].Sex
# Out:
# 78       male
# 164      male
# 172    female
# 183      male
# 305      male
# 381    female
# 386      male
# 469    female
# 644    female
# 755      male
# 788      male
# 803      male
# 827      male
# 831      male
# Name: Sex, dtype: object

# %%
titanic.loc[titanic.Age<=1, 'Sex']  # loc method to seek values
# Out:
# 78       male
# 164      male
# 172    female
# 183      male
# 305      male
# 381    female
# 386      male
# 469    female
# 644    female
# 755      male
# 788      male
# 803      male
# 827      male
# 831      male
# Name: Sex, dtype: object

# %% [markdown]
# ## multiple filtering

# %%
titanic[(titanic.Age<=1) & (titanic.Sex=='female')]   # & for and | for or
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 172          173         1       3   Johnson, Miss. Eleanor Ileen  female
# 381          382         1       3    Nakid, Miss. Maria ("Mary")  female
# 469          470         1       3  Baclini, Miss. Helene Barbara  female
# 644          645         1       3         Baclini, Miss. Eugenie  female
#
#       Age  Ticket     Fare Cabin Embarked Ticket_Cabin_ignoreNaN
# 172  1.00  347742  11.1333   NaN        S                347742,
# 381  1.00    2653  15.7417   NaN        C                  2653,
# 469  0.75    2666  19.2583   NaN        C                  2666,
# 644  0.75    2666  19.2583   NaN        C                  2666,

# %%
titanic[(titanic.Age<=1) & (titanic.Sex=='female')].Name
# Out:
# 172     Johnson, Miss. Eleanor Ileen
# 381      Nakid, Miss. Maria ("Mary")
# 469    Baclini, Miss. Helene Barbara
# 644           Baclini, Miss. Eugenie
# Name: Name, dtype: object

# %%
titanic[titanic.Name.isin(['Johnson, Miss. Eleanor Ileen', 'Baclini, Miss. Helene Barbara', 'Baclini, Miss. Eugenie'])]
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 172          173         1       3   Johnson, Miss. Eleanor Ileen  female
# 469          470         1       3  Baclini, Miss. Helene Barbara  female
# 644          645         1       3         Baclini, Miss. Eugenie  female
#
#       Age  Ticket     Fare Cabin Embarked Ticket_Cabin_ignoreNaN
# 172  1.00  347742  11.1333   NaN        S                347742,
# 469  0.75    2666  19.2583   NaN        C                  2666,
# 644  0.75    2666  19.2583   NaN        C                  2666,

# %% [markdown]
# # drop all non-numeric columns from a DataFrame

# %%
import numpy
titanic.select_dtypes(include=[numpy.number]).head()
# Out:
#    PassengerId  Survived  Pclass   Age     Fare
# 0            1         0       3  22.0   7.2500
# 1            2         1       1  38.0  71.2833
# 2            3         1       3  26.0   7.9250
# 3            4         1       1  35.0  53.1000
# 4            5         0       3  35.0   8.0500

# %% [markdown]
# # calculating mean of each column

# %%
titanic.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# Fare            32.204208
# dtype: float64

# %%
titanic.mean(axis=0)  # titanic.mean(axis=1)  row wise mean
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# Fare            32.204208
# dtype: float64

# %% [markdown]
# # string operations .upper() .contains() .replace()

# %%
titanic.columns.str.upper()
# Out:
# Index(['PASSENGERID', 'SURVIVED', 'PCLASS', 'NAME', 'SEX', 'AGE', 'TICKET',
#        'FARE', 'CABIN', 'EMBARKED', 'TICKET_CABIN_IGNORENAN'],
#       dtype='object')

# %%
titanic.columns.str.lower()
# Out:
# Index(['passengerid', 'survived', 'pclass', 'name', 'sex', 'age', 'ticket',
#        'fare', 'cabin', 'embarked', 'ticket_cabin_ignorenan'],
#       dtype='object')

# %%
titanic.columns.str.replace(' ', '_')
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'Ticket_Cabin_ignoreNaN'],
#       dtype='object')

# %%
titanic[titanic.Name.str.contains('Mary')]
# Out:
#      PassengerId  Survived  Pclass  \
# 15            16         1       2
# 32            33         1       3
# 318          319         1       1
# 322          323         1       2
# 347          348         1       3
# 358          359         1       3
# 359          360         1       3
# 381          382         1       3
# 383          384         1       1
# 472          473         1       2
# 501          502         0       3
# 502          503         0       3
# 518          519         1       2
# 573          574         1       3
# 593          594         0       3
# 635          636         1       2
# 767          768         0       3
# 772          773         0       2
# 853          854         1       1
# 856          857         1       1
#
#                                                   Name     Sex   Age  \
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 32                            Glynn, Miss. Mary Agatha  female   NaN
# ...

# %%
titanic.columns.str.replace(' ','_') # replaces spaces in columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'Ticket_Cabin_ignoreNaN'],
#       dtype='object')

# %% [markdown]
# # change data types of the pandas series

# %%
titanic.dtypes
# Out:
# PassengerId                 int64
# Survived                    int64
# Pclass                      int64
# Name                       object
# Sex                        object
# Age                       float64
# Ticket                     object
# Fare                      float64
# Cabin                      object
# Embarked                   object
# Ticket_Cabin_ignoreNaN     object
# dtype: object

# %%
titanic['Pclass'] = titanic.Pclass.astype(float)
titanic.dtypes
# Out:
# PassengerId                 int64
# Survived                    int64
# Pclass                    float64
# Name                       object
# Sex                        object
# Age                       float64
# Ticket                     object
# Fare                      float64
# Cabin                      object
# Embarked                   object
# Ticket_Cabin_ignoreNaN     object
# dtype: object

# %%
titanic['Pclass'] = titanic.Pclass.astype(int)
titanic.dtypes
# Out:
# PassengerId                 int64
# Survived                    int64
# Pclass                      int32
# Name                       object
# Sex                        object
# Age                       float64
# Ticket                     object
# Fare                      float64
# Cabin                      object
# Embarked                   object
# Ticket_Cabin_ignoreNaN     object
# dtype: object

# %% [markdown]
# #### alternatively, change the data type of a Series while reading in a file

# %%
# titanic =  pd.read_csv('titanic.csv', dtype={'Pclass':int})

# %% [markdown]
# # groupby()

# %% [markdown]
# ### lets calculate mean age per passenger class

# %%
titanic.groupby('Pclass').Age.mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
# %matplotlib inline

# %%
titanic.groupby('Pclass').Age.mean().plot(kind='bar')

# %% [markdown]
# # The infamous missing values NaN

# %%
titanic.isnull().head()
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  Ticket   Fare  Cabin  \
# 0        False     False   False  False  False  False   False  False   True
# 1        False     False   False  False  False  False   False  False  False
# 2        False     False   False  False  False  False   False  False   True
# 3        False     False   False  False  False  False   False  False  False
# 4        False     False   False  False  False  False   False  False   True
#
#    Embarked  Ticket_Cabin_ignoreNaN
# 0     False                   False
# 1     False                   False
# 2     False                   False
# 3     False                   False
# 4     False                   False

# %%
titanic.isnull().sum()
# Out:
# PassengerId                 0
# Survived                    0
# Pclass                      0
# Name                        0
# Sex                         0
# Age                       177
# Ticket                      0
# Fare                        0
# Cabin                     687
# Embarked                    2
# Ticket_Cabin_ignoreNaN      0
# dtype: int64

# %%
titanic.shape
# Out:
# (891, 11)

# %% [markdown]
# #### There are 891 rows and 11 columns , i.e for cabin out of 891 values 687 values is missing ; now, how to work with clean data with no missing values ; lets drop all rows with missing values

# %%
titanic.dropna(how = 'all').shape  # drop a row if all the values are missing , final dataframe is same since no row is completely NaNs
# Out:
# (891, 11)

# %%
titanic.dropna(how = 'any').shape  # 891-183 = 708 rows dropped
# Out:
# (183, 11)

# %%
titanic.dropna(subset=['Name','Survived'] , how = 'any').shape # so all passenger names and survival info is available
# Out:
# (891, 11)

# %%
titanic.dropna(subset=['Name','Age'] , how = 'any').shape    # some rows dropped in which the passenger age info is not available
# Out:
# (714, 11)

# %%
titanic.shape
# Out:
# (891, 11)

# %%
titanic.Age.value_counts(dropna=False).head()
# Out:
# NaN     177
# 24.0     30
# 22.0     27
# 18.0     26
# 28.0     25
# Name: Age, dtype: int64

# %% [markdown]
# #### how about filling those Age values with some meaningful info so that our work becomes easier and meaningful

# %%
titanic.Age.fillna('not available').head(10)
# Out:
# 0               22
# 1               38
# 2               26
# 3               35
# 4               35
# 5    not available
# 6               54
# 7                2
# 8               27
# 9               14
# Name: Age, dtype: object

# %%
titanic.Age.fillna(method='bfill').tail(15) # fill missing values using "backward fill" strategy
# Out:
# 876    20.0
# 877    19.0
# 878    56.0
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888    26.0
# 889    26.0
# 890    32.0
# Name: Age, dtype: float64

# %%
titanic.Age.fillna(method='ffill').tail(15)  # forward fill
# Out:
# 876    20.0
# 877    19.0
# 878    19.0
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888    19.0
# 889    26.0
# 890    32.0
# Name: Age, dtype: float64

# %% [markdown]
# # .loc .iloc Indexing

# %%
titanic.loc[40,'Name'] # loc is index by column name selection
# Out:
# 'Ahlin, Mrs. Johan (Johanna Persdotter Larsson)'

# %%
titanic.iloc[40,3] # iloc ; index by column number selection
# Out:
# 'Ahlin, Mrs. Johan (Johanna Persdotter Larsson)'

# %%
titanic.loc[[0,8,15], :]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 8             9         1       3
# 15           16         1       2
#
#                                                  Name     Sex   Age  \
# 0                             Braund, Mr. Owen Harris    male  22.0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#        Ticket     Fare Cabin Embarked Ticket_Cabin_ignoreNaN
# 0   A/5 21171   7.2500   NaN        S             A/5 21171,
# 8      347742  11.1333   NaN        S                347742,
# 15     248706  16.0000   NaN        S                248706,

# %%
titanic.iloc[0:15,4:10]
# Out:
#        Sex   Age            Ticket     Fare Cabin Embarked
# 0     male  22.0         A/5 21171   7.2500   NaN        S
# 1   female  38.0          PC 17599  71.2833   C85        C
# 2   female  26.0  STON/O2. 3101282   7.9250   NaN        S
# 3   female  35.0            113803  53.1000  C123        S
# 4     male  35.0            373450   8.0500   NaN        S
# 5     male   NaN            330877   8.4583   NaN        Q
# 6     male  54.0             17463  51.8625   E46        S
# 7     male   2.0            349909  21.0750   NaN        S
# 8   female  27.0            347742  11.1333   NaN        S
# 9   female  14.0            237736  30.0708   NaN        C
# 10  female   4.0           PP 9549  16.7000    G6        S
# 11  female  58.0            113783  26.5500  C103        S
# 12    male  20.0         A/5. 2151   8.0500   NaN        S
# 13    male  39.0            347082  31.2750   NaN        S
# 14  female  14.0            350406   7.8542   NaN        S

# %%
titanic.loc[0:5, :] # inclusive 0 through 5 rows and all columns
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
#
#              Ticket     Fare Cabin Embarked Ticket_Cabin_ignoreNaN
# 0         A/5 21171   7.2500   NaN        S             A/5 21171,
# 1          PC 17599  71.2833   C85        C           PC 17599,C85
# ...

# %%
titanic.loc[0:5] # is same as titanic.loc[0:5, :]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
#
#              Ticket     Fare Cabin Embarked Ticket_Cabin_ignoreNaN
# 0         A/5 21171   7.2500   NaN        S             A/5 21171,
# 1          PC 17599  71.2833   C85        C           PC 17599,C85
# ...

# %%
titanic.loc[15:25, ['Name', 'Ticket']]
# Out:
#                                                  Name  Ticket
# 15                   Hewlett, Mrs. (Mary D Kingcome)   248706
# 16                               Rice, Master. Eugene  382652
# 17                       Williams, Mr. Charles Eugene  244373
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  345763
# 19                            Masselmani, Mrs. Fatima    2649
# 20                               Fynney, Mr. Joseph J  239865
# 21                              Beesley, Mr. Lawrence  248698
# 22                        McGowan, Miss. Anna "Annie"  330923
# 23                       Sloper, Mr. William Thompson  113788
# 24                      Palsson, Miss. Torborg Danira  349909
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  347077

# %%
titanic.loc[titanic.Pclass == 3, :].head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 4             5         0       3
# 5             6         0       3
# 7             8         0       3
# 8             9         1       3
# 10           11         1       3
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  \
# 0                             Braund, Mr. Owen Harris    male  22.0
# 2                              Heikkinen, Miss. Laina  female  26.0
# 4                            Allen, Mr. William Henry    male  35.0
# 5                                    Moran, Mr. James    male   NaN
# 7                      Palsson, Master. Gosta Leonard    male   2.0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0
# ...

# %%
titanic.loc[titanic.Pclass == 3, : 'Name'].head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 4             5         0       3
# 5             6         0       3
# 7             8         0       3
# 8             9         1       3
# 10           11         1       3
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name
# 0                             Braund, Mr. Owen Harris
# 2                              Heikkinen, Miss. Laina
# 4                            Allen, Mr. William Henry
# 5                                    Moran, Mr. James
# 7                      Palsson, Master. Gosta Leonard
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                    Sandstrom, Miss. Marguerite Rut
# 12                     Saundercock, Mr. William Henry
# 13                        Andersson, Mr. Anders Johan
# ...

# %% [markdown]
# #### how to set a column as index of the dataframe

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.set_index('Name', inplace=True) # change inplace = True if needed

# %%
titanic.reset_index(inplace=True)  # reset index to orinal

# %%
titanic.head()
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                           Allen, Mr. William Henry            5         0
#
#    Pclass     Sex   Age            Ticket     Fare Cabin Embarked  \
# 0       3    male  22.0         A/5 21171   7.2500   NaN        S
# 1       1  female  38.0          PC 17599  71.2833   C85        C
# 2       3  female  26.0  STON/O2. 3101282   7.9250   NaN        S
# 3       1  female  35.0            113803  53.1000  C123        S
# 4       3    male  35.0            373450   8.0500   NaN        S
#
#   Ticket_Cabin_ignoreNaN
# 0             A/5 21171,
# 1           PC 17599,C85
# 2      STON/O2. 3101282,
# ...

# %% [markdown]
# # sorting

# %%
titanic.Name.sort_values()
# Out:
# 845                                Abbing, Mr. Anthony
# 746                        Abbott, Mr. Rossmore Edward
# 279                   Abbott, Mrs. Stanton (Rosa Hunt)
# 308                                Abelson, Mr. Samuel
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)
# 365                     Adahl, Mr. Mauritz Nils Martin
# 401                                    Adams, Mr. John
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# 855                         Aks, Mrs. Sam (Leah Rosen)
# 207                        Albimona, Mr. Nassef Cassem
# 810                             Alexander, Mr. William
# 840                        Alhomaki, Mr. Ilmari Rudolf
# 210                                     Ali, Mr. Ahmed
# 784                                   Ali, Mr. William
# 730                      Allen, Miss. Elisabeth Walton
# 4                             Allen, Mr. William Henry
# 305                     Allison, Master. Hudson Trevor
# ...

# %% [markdown]
# # dummy variables  - categorical features

# %%
titanic['Sex_male'] = titanic.Sex.map({'male':1, 'female' : 0})
titanic.head(25)
# Out:
#                                                  Name  PassengerId  Survived  \
# 0                             Braund, Mr. Owen Harris            1         0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                              Heikkinen, Miss. Laina            3         1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                            Allen, Mr. William Henry            5         0
# 5                                    Moran, Mr. James            6         0
# 6                             McCarthy, Mr. Timothy J            7         0
# 7                      Palsson, Master. Gosta Leonard            8         0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            9         1
# 9                 Nasser, Mrs. Nicholas (Adele Achem)           10         1
# 10                    Sandstrom, Miss. Marguerite Rut           11         1
# ...

# %% [markdown]
# # duplicates

# %%
titanic.Ticket.duplicated().head(25) # first occurence of the duplicates
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# Name: Ticket, dtype: bool

# %%
titanic.Ticket.duplicated().value_counts()  # 210 same tickets for all family members
# Out:
# False    681
# True     210
# Name: Ticket, dtype: int64

# %%
titanic.Ticket.drop_duplicates(keep='first')  # inplace = False by default ,
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
# 5                330877
# 6                 17463
# 7                349909
# 8                347742
# 9                237736
# 10              PP 9549
# 11               113783
# 12            A/5. 2151
# 13               347082
# 14               350406
# 15               248706
# 16               382652
# 17               244373
# 18               345763
# 19                 2649
# 20               239865
# 21               248698
# 22               330923
# 23               113788
# 25               347077
# 26                 2631
# 27                19950
# 28               330959
# 29               349216
# 30             PC 17601
#              ...
# 844              315090
# 845           C.A. 5547
# 847              349213
# 851              347060
# 853            PC 17592
# 855              392091
# 857              113055
# ...

# %%
titanic.Ticket.drop_duplicates(keep='last')  # inplace = False by default ,
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 4                373450
# 5                330877
# 6                 17463
# 11               113783
# 12            A/5. 2151
# 14               350406
# 15               248706
# 17               244373
# 18               345763
# 19                 2649
# 21               248698
# 22               330923
# 23               113788
# 26                 2631
# 28               330959
# 29               349216
# 30             PC 17601
# 32               335677
# 33           C.A. 24579
# 36                 2677
# 37           A./5. 2152
# 40                 7546
# 42               349253
# 44               330958
# 45      S.C./A.4. 23567
# 46               370371
# 47                14311
#              ...
# 861               28134
# 862               17466
# 863            CA. 2343
# 864              233866
# 865              236852
# 866       SC/PARIS 2149
# 867            PC 17590
# ...

# %%
titanic.Ticket.drop_duplicates(keep=False)  # inplace = False by default , # removes all occurences of duplicates
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 4                373450
# 5                330877
# 6                 17463
# 11               113783
# 12            A/5. 2151
# 14               350406
# 15               248706
# 17               244373
# 18               345763
# 19                 2649
# 21               248698
# 22               330923
# 23               113788
# 26                 2631
# 28               330959
# 29               349216
# 30             PC 17601
# 32               335677
# 33           C.A. 24579
# 36                 2677
# 37           A./5. 2152
# 40                 7546
# 42               349253
# 44               330958
# 45      S.C./A.4. 23567
# 46               370371
# 47                14311
#              ...
# 844              315090
# 845           C.A. 5547
# 847              349213
# 851              347060
# 853            PC 17592
# 855              392091
# 857              113055
# ...

# %%
titanic.drop_duplicates(keep=False)  # if rows are duplicates
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# 5                                     Moran, Mr. James            6         0
# 6                              McCarthy, Mr. Timothy J            7         0
# 7                       Palsson, Master. Gosta Leonard            8         0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            9         1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)           10         1
# 10                     Sandstrom, Miss. Marguerite Rut           11         1
# ...

# %% [raw]
# References :
#
# https://pandas.pydata.org/pandas-docs/stable/getting_started/tutorials.html
# http://conference.scipy.org/scipy2013/tutorial_detail.php?id=109 Christopher Fonnesbeck from SciPy 2013
